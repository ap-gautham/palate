# %%
import pandas as pd

# %%
temp = pd.read_csv('/Users/apgautham/Random/08_MovieRecommendation/data/letterboxd/raw/gsimonx37/themes.csv')

# %%
len(temp['theme'].unique())
# Out:
# 109

# %%
temp2 = temp['name'].value_counts()

# %%
len(temp2[temp2>5])
# Out:
# 185541

# %%
temp2
# Out:
# name
# Mel Blanc            1058
# Bess Flowers          696
# Jagathy Sreekumar     635
# Eric Roberts          587
# Brahmanandam          581
#                      ...
# Ari Arad                1
# Jenny Fulle             1
# E. Bennett Walsh        1
# Seppo Mattila           1
# 线雨轩                     1
# Name: count, Length: 1600662, dtype: int64
